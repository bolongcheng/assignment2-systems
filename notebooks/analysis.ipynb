# %%
import pandas as pd

# %matplotlib inline

# %%
fwd_data = pd.read_csv("../benchmarks/pytorch_simple_profile_fwd.csv", index_col="iteration")
fwd_data.boxplot()

# %%
fwd_data.describe()

# %%
bwd_data = pd.read_csv("../benchmarks/pytorch_simple_profile_bwd.csv", index_col="iteration")
bwd_data.boxplot()

# %%
bwd_data.describe()

# %%
opt_data = pd.read_csv("../benchmarks/pytorch_simple_profile_opt.csv", index_col="iteration")
opt_data.boxplot()

# %%
opt_data.describe()

# %%
fwd0_data = pd.read_csv("../benchmarks/pytorch_simple_profile_fwd_warmup0.csv", index_col="iteration")
fwd0_data.boxplot()

# %%
bwd0_data = pd.read_csv("../benchmarks/pytorch_simple_profile_bwd_warmup0.csv", index_col="iteration")
bwd0_data.boxplot()

# %%
opt0_data = pd.read_csv("../benchmarks/pytorch_simple_profile_opt_warmup0.csv", index_col="iteration")
opt0_data.boxplot()

# %% [markdown]
# ## Check precisions

# %%
fwd_full_data = pd.read_csv("../benchmarks/A100/pytorch_simple_profile_fwd_warmup5_all.csv", index_col="iteration")
fwd_full_data[["small/fwd", "medium/fwd", "large/fwd"]].boxplot()

fwd_bf16_data = pd.read_csv("../benchmarks/A100/pytorch_simple_profile_fwd_warmup5_all_bf16.csv", index_col="iteration")
fwd_bf16_data.boxplot(color="r")

# %%
bwd_full_data = pd.read_csv("../benchmarks/A100/pytorch_simple_profile_bwd_warmup5_all.csv", index_col="iteration")
bwd_full_data.boxplot()

bwd_bf16_data = pd.read_csv("../benchmarks/A100/pytorch_simple_profile_bwd_warmup5_all_bf16.csv", index_col="iteration")
bwd_bf16_data.boxplot(color="r")

# %%
opt_full_data = pd.read_csv("../benchmarks/A100/pytorch_simple_profile_opt_warmup5_all.csv", index_col="iteration")
opt_full_data.boxplot()

opt_bf16_data = pd.read_csv("../benchmarks/A100/pytorch_simple_profile_opt_warmup5_all_bf16.csv", index_col="iteration")
opt_bf16_data.boxplot(color="r")
