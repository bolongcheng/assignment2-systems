# %%
import torch

s = torch.tensor(0, dtype=torch.float32)
for i in range(1000):
    s += torch.tensor(0.01, dtype=torch.float32)
print(s)

s = torch.tensor(0, dtype=torch.float16)
for i in range(1000):
    s += torch.tensor(0.01, dtype=torch.float16)
print(s)

s = torch.tensor(0, dtype=torch.float32)
for i in range(1000):
    s += torch.tensor(0.01, dtype=torch.float16)
print(s)

s = torch.tensor(0, dtype=torch.float32)
for i in range(1000):
    x = torch.tensor(0.01, dtype=torch.float16)
    s += x.type(torch.float32)
print(s)

# %%
from scripts.toy_model import ToyModel
from scripts.benchmark_base import get_random_data_batch

# %%
import torch
from cs336_basics.nn_utils import cross_entropy

model = ToyModel(512, 36)

for m in model.modules():
    if hasattr(m, "weight"):
        print(f"Module: {m}, Weight dtype: {m.weight.dtype}")
x = torch.rand((64, 512))
y = torch.randint(0, 36, (64, 1))
print(y.view(-1).shape)
pred = model(x)
print(pred.dtype)
loss = cross_entropy(pred.view(-1, pred.shape[-1]), y.view(-1))
print(loss.dtype)

# %%
y.shape

# %%
x.shape
