# %%
import pandas as pd

# %matplotlib inline

# %%
df2 = pd.read_csv("../benchmarks/allreduce_2_node.csv")
df2.boxplot()

df4 = pd.read_csv("../benchmarks/allreduce_4_node.csv")
df4.boxplot(color='red')

df6 = pd.read_csv("../benchmarks/allreduce_6_node.csv")
df6.boxplot(color='green')

# %%
ddp_df = pd.read_csv("../benchmarks/ddp_benchmark_xl_naive_ws=2_bs=4_cl=512.csv")
ddp_df.set_index("iteration").boxplot()
print(ddp_df["total_ms"].median())
print(ddp_df["comm_ms"].median())

# %%
ddp_df = pd.read_csv("../benchmarks/ddp_benchmark_xl_flatten_ws=2_bs=4_cl=512.csv")
ddp_df.set_index("iteration").boxplot()
print(ddp_df["total_ms"].median())
print(ddp_df["comm_ms"].median())

# %%
ddp_df = pd.read_csv("../benchmarks/ddp_benchmark_xl_overlap_ws=2_bs=4_cl=512.csv")
ddp_df.set_index("iteration").boxplot()
print(ddp_df["total_ms"].median())
print(ddp_df["comm_ms"].median())

# %%
ddp_df = pd.read_csv("../benchmarks/ddp_benchmark_xl_overlap_sharded_ws=2_bs=4_cl=512.csv")
ddp_df.set_index("iteration").boxplot()
print(ddp_df["total_ms"].median())
print(ddp_df["comm_ms"].median())
